# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x_np = np.asarray(x)
    z_scores_np = (x_np - x_np.mean()) / x_np.std()
    # Min-Max scaling

    np_minmax = (x_np - x_np.min()) / (x_np.max() - x_np.min())
    return np_minmax


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
n_classes = 10
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return np.eye(n_classes)[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,(None,*image_shape),name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,(None,n_classes),name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,(None),name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    weight=tf.Variable(tf.random_normal([conv_ksize[0],conv_ksize[1],x_tensor.get_shape().as_list()[3],
                                         conv_num_outputs], mean=0.0, stddev=0.1))
    baise=tf.Variable(tf.zeros([conv_num_outputs]))
    x=tf.nn.conv2d(x_tensor,weight,strides=[1,conv_strides[0],conv_strides[1],1],padding='SAME')
    x=tf.nn.relu(x)
    return tf.nn.max_pool(x,ksize=[1,pool_ksize[0],pool_ksize[1],1],strides=[1,pool_strides[0],pool_strides[1],1],padding='SAME') 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    a=x_tensor.get_shape().as_list();
    #print(a);
    return tf.reshape(x_tensor,[-1,a[1]*a[2]*a[3]])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    w=tf.Variable(tf.random_normal([x_tensor.get_shape().as_list()[1],num_outputs],mean=0.0,stddev=0.1))
    d=tf.Variable(tf.zeros([num_outputs]))
    f=tf.add(tf.matmul(x_tensor,w),d)
    return tf.nn.relu(f)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    wo=tf.Variable(tf.random_normal([x_tensor.get_shape().as_list()[1],num_outputs],mean=0.0,stddev=0.1))
    do=tf.Variable(tf.zeros([num_outputs]))
    
    
    return tf.add(tf.matmul(x_tensor,wo),do)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    conv_val=conv2d_maxpool(x, conv_num_outputs=32, conv_ksize=(5,5), conv_strides=(2,2), pool_ksize=(2,2), pool_strides=(2,2))
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat_val=flatten(conv_val)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully_val=fully_conn(flat_val, 512//2)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    global y
    val=output(fully_val, num_outputs=y.get_shape().as_list()[1])
    
    # TODO: return output
    return val


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
        
    session.run(optimizer,feed_dict={
        x:feature_batch,
        y:label_batch,
        keep_prob:keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss= session.run(cost,feed_dict={
        x:feature_batch,
        y:label_batch,
        keep_prob:1.
    })


    valid=session.run(accuracy,feed_dict={
        x:valid_features,
        y:valid_labels,
        keep_prob:1.
    })
    print('loss{:10.6f} validation{:.6f}'.format(loss,valid))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 75
batch_size = 92
keep_probability = 0.4

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss  1.990338 validation0.355000
# Epoch  2, CIFAR-10 Batch 1:  loss  1.808351 validation0.444400
# Epoch  3, CIFAR-10 Batch 1:  loss  1.665274 validation0.478400
# Epoch  4, CIFAR-10 Batch 1:  loss  1.526306 validation0.498600
# Epoch  5, CIFAR-10 Batch 1:  loss  1.427877 validation0.507800
# Epoch  6, CIFAR-10 Batch 1:  loss  1.282854 validation0.521800
# Epoch  7, CIFAR-10 Batch 1:  loss  1.196144 validation0.524800
# Epoch  8, CIFAR-10 Batch 1:  loss  1.096185 validation0.532200
# Epoch  9, CIFAR-10 Batch 1:  loss  0.987353 validation0.537600
# Epoch 10, CIFAR-10 Batch 1:  loss  0.895014 validation0.536000
# Epoch 11, CIFAR-10 Batch 1:  loss  0.811007 validation0.542000
# Epoch 12, CIFAR-10 Batch 1:  loss  0.764480 validation0.543800
# Epoch 13, CIFAR-10 Batch 1:  loss  0.726443 validation0.534600
# Epoch 14, CIFAR-10 Batch 1:  loss  0.638652 validation0.532600
# Epoch 15, CIFAR-10 Batch 1:  loss  0.572525 validation0.533600
# Epoch 16, CIFAR-10 Batch 1:  loss  0.490811 validation0.540200
# Epoch 17, CIFAR-10 Batch 1:  loss  0.448037 validation0.536800
# Epoch 18, CIFAR-10 Batch 1:  loss  0.448121 validation0.529400
# Epoch 19, CIFAR-10 Batch 1:  loss  0.362076 validation0.528200
# Epoch 20, CIFAR-10 Batch 1:  loss  0.293106 validation0.521600
# Epoch 21, CIFAR-10 Batch 1:  loss  0.239197 validation0.530400
# Epoch 22, CIFAR-10 Batch 1:  loss  0.228774 validation0.528800
# Epoch 23, CIFAR-10 Batch 1:  loss  0.277610 validation0.518800
# Epoch 24, CIFAR-10 Batch 1:  loss  0.241325 validation0.527800
# Epoch 25, CIFAR-10 Batch 1:  loss  0.180175 validation0.538800
# Epoch 26, CIFAR-10 Batch 1:  loss  0.158874 validation0.528800
# Epoch 27, CIFAR-10 Batch 1:  loss  0.107617 validation0.534400
# Epoch 28, CIFAR-10 Batch 1:  loss  0.096358 validation0.533000
# Epoch 29, CIFAR-10 Batch 1:  loss  0.109362 validation0.524600
# Epoch 30, CIFAR-10 Batch 1:  loss  0.104557 validation0.529800
# Epoch 31, CIFAR-10 Batch 1:  loss  0.063723 validation0.544400
# Epoch 32, CIFAR-10 Batch 1:  loss  0.087284 validation0.515800
# Epoch 33, CIFAR-10 Batch 1:  loss  0.078773 validation0.519600
# Epoch 34, CIFAR-10 Batch 1:  loss  0.060109 validation0.530600
# Epoch 35, CIFAR-10 Batch 1:  loss  0.037941 validation0.546000
# Epoch 36, CIFAR-10 Batch 1:  loss  0.049419 validation0.544600
# Epoch 37, CIFAR-10 Batch 1:  loss  0.038570 validation0.539400
# Epoch 38, CIFAR-10 Batch 1:  loss  0.027108 validation0.549400
# Epoch 39, CIFAR-10 Batch 1:  loss  0.026913 validation0.551600
# Epoch 40, CIFAR-10 Batch 1:  loss  0.031711 validation0.534600
# Epoch 41, CIFAR-10 Batch 1:  loss  0.039716 validation0.531200
# Epoch 42, CIFAR-10 Batch 1:  loss  0.040707 validation0.530800
# Epoch 43, CIFAR-10 Batch 1:  loss  0.025501 validation0.541800
# Epoch 44, CIFAR-10 Batch 1:  loss  0.023902 validation0.520400
# Epoch 45, CIFAR-10 Batch 1:  loss  0.018766 validation0.548400
# Epoch 46, CIFAR-10 Batch 1:  loss  0.014574 validation0.548600
# Epoch 47, CIFAR-10 Batch 1:  loss  0.007823 validation0.547800
# Epoch 48, CIFAR-10 Batch 1:  loss  0.007648 validation0.552400
# Epoch 49, CIFAR-10 Batch 1:  loss  0.006085 validation0.559400
# Epoch 50, CIFAR-10 Batch 1:  loss  0.008591 validation0.553600
# Epoch 51, CIFAR-10 Batch 1:  loss  0.007822 validation0.544800
# Epoch 52, CIFAR-10 Batch 1:  loss  0.005569 validation0.540200
# Epoch 53, CIFAR-10 Batch 1:  loss  0.005819 validation0.548400
# Epoch 54, CIFAR-10 Batch 1:  loss  0.004861 validation0.555400
# Epoch 55, CIFAR-10 Batch 1:  loss  0.003085 validation0.553200
# Epoch 56, CIFAR-10 Batch 1:  loss  0.002521 validation0.556400
# Epoch 57, CIFAR-10 Batch 1:  loss  0.002469 validation0.550600
# Epoch 58, CIFAR-10 Batch 1:  loss  0.002704 validation0.551200
# Epoch 59, CIFAR-10 Batch 1:  loss  0.002152 validation0.549800
# Epoch 60, CIFAR-10 Batch 1:  loss  0.002620 validation0.547400
# Epoch 61, CIFAR-10 Batch 1:  loss  0.002744 validation0.541600
# Epoch 62, CIFAR-10 Batch 1:  loss  0.001793 validation0.550600
# Epoch 63, CIFAR-10 Batch 1:  loss  0.001898 validation0.558600
# Epoch 64, CIFAR-10 Batch 1:  loss  0.002160 validation0.559200
# Epoch 65, CIFAR-10 Batch 1:  loss  0.001818 validation0.563000
# Epoch 66, CIFAR-10 Batch 1:  loss  0.030274 validation0.519200
# Epoch 67, CIFAR-10 Batch 1:  loss  0.051466 validation0.518400
# Epoch 68, CIFAR-10 Batch 1:  loss  0.026110 validation0.529000
# Epoch 69, CIFAR-10 Batch 1:  loss  0.013729 validation0.545400
# Epoch 70, CIFAR-10 Batch 1:  loss  0.005504 validation0.548400
# Epoch 71, CIFAR-10 Batch 1:  loss  0.003703 validation0.552800
# Epoch 72, CIFAR-10 Batch 1:  loss  0.003069 validation0.557000
# Epoch 73, CIFAR-10 Batch 1:  loss  0.002357 validation0.560400
# Epoch 74, CIFAR-10 Batch 1:  loss  0.001861 validation0.560400
# Epoch 75, CIFAR-10 Batch 1:  loss  0.001583 validation0.561200

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss  1.780467 validation0.387600
# Epoch  1, CIFAR-10 Batch 2:  loss  1.423810 validation0.467600
# Epoch  1, CIFAR-10 Batch 3:  loss  1.276136 validation0.512200
# Epoch  1, CIFAR-10 Batch 4:  loss  1.316746 validation0.525800
# Epoch  1, CIFAR-10 Batch 5:  loss  1.316009 validation0.537600
# Epoch  2, CIFAR-10 Batch 1:  loss  1.453046 validation0.552600
# Epoch  2, CIFAR-10 Batch 2:  loss  1.095310 validation0.551000
# Epoch  2, CIFAR-10 Batch 3:  loss  0.962539 validation0.561400
# Epoch  2, CIFAR-10 Batch 4:  loss  1.124481 validation0.572000
# Epoch  2, CIFAR-10 Batch 5:  loss  1.068362 validation0.579200
# Epoch  3, CIFAR-10 Batch 1:  loss  1.337050 validation0.589200
# Epoch  3, CIFAR-10 Batch 2:  loss  0.942027 validation0.586800
# Epoch  3, CIFAR-10 Batch 3:  loss  0.808894 validation0.593600
# Epoch  3, CIFAR-10 Batch 4:  loss  1.018954 validation0.590800
# Epoch  3, CIFAR-10 Batch 5:  loss  0.860267 validation0.607400
# Epoch  4, CIFAR-10 Batch 1:  loss  1.250442 validation0.605200
# Epoch  4, CIFAR-10 Batch 2:  loss  0.836317 validation0.607200
# Epoch  4, CIFAR-10 Batch 3:  loss  0.691436 validation0.616200
# Epoch  4, CIFAR-10 Batch 4:  loss  0.891607 validation0.620000
# Epoch  4, CIFAR-10 Batch 5:  loss  0.717588 validation0.625000
# Epoch  5, CIFAR-10 Batch 1:  loss  1.159107 validation0.619200
# Epoch  5, CIFAR-10 Batch 2:  loss  0.717584 validation0.620400
# Epoch  5, CIFAR-10 Batch 3:  loss  0.590414 validation0.622600
# Epoch  5, CIFAR-10 Batch 4:  loss  0.795262 validation0.630400
# Epoch  5, CIFAR-10 Batch 5:  loss  0.640090 validation0.629000
# Epoch  6, CIFAR-10 Batch 1:  loss  1.092292 validation0.632400
# Epoch  6, CIFAR-10 Batch 2:  loss  0.630196 validation0.620400
# Epoch  6, CIFAR-10 Batch 3:  loss  0.531396 validation0.630800
# Epoch  6, CIFAR-10 Batch 4:  loss  0.709863 validation0.632600
# Epoch  6, CIFAR-10 Batch 5:  loss  0.567932 validation0.625400
# Epoch  7, CIFAR-10 Batch 1:  loss  1.069504 validation0.630800
# Epoch  7, CIFAR-10 Batch 2:  loss  0.590240 validation0.622400
# Epoch  7, CIFAR-10 Batch 3:  loss  0.426837 validation0.628000
# Epoch  7, CIFAR-10 Batch 4:  loss  0.647591 validation0.626400
# Epoch  7, CIFAR-10 Batch 5:  loss  0.472947 validation0.628600
# Epoch  8, CIFAR-10 Batch 1:  loss  1.008381 validation0.625600
# Epoch  8, CIFAR-10 Batch 2:  loss  0.546912 validation0.624800
# Epoch  8, CIFAR-10 Batch 3:  loss  0.389187 validation0.618800
# Epoch  8, CIFAR-10 Batch 4:  loss  0.602343 validation0.620800
# Epoch  8, CIFAR-10 Batch 5:  loss  0.394829 validation0.635800
# Epoch  9, CIFAR-10 Batch 1:  loss  0.936685 validation0.619000
# Epoch  9, CIFAR-10 Batch 2:  loss  0.497458 validation0.627800
# Epoch  9, CIFAR-10 Batch 3:  loss  0.332915 validation0.620200
# Epoch  9, CIFAR-10 Batch 4:  loss  0.501367 validation0.624200
# Epoch  9, CIFAR-10 Batch 5:  loss  0.356317 validation0.618600
# Epoch 10, CIFAR-10 Batch 1:  loss  0.828249 validation0.615200
# Epoch 10, CIFAR-10 Batch 2:  loss  0.431082 validation0.627800
# Epoch 10, CIFAR-10 Batch 3:  loss  0.289860 validation0.621400
# Epoch 10, CIFAR-10 Batch 4:  loss  0.427929 validation0.613800
# Epoch 10, CIFAR-10 Batch 5:  loss  0.285762 validation0.625400
# Epoch 11, CIFAR-10 Batch 1:  loss  0.698557 validation0.618000
# Epoch 11, CIFAR-10 Batch 2:  loss  0.481426 validation0.598800
# Epoch 11, CIFAR-10 Batch 3:  loss  0.283122 validation0.606400
# Epoch 11, CIFAR-10 Batch 4:  loss  0.403553 validation0.603800
# Epoch 11, CIFAR-10 Batch 5:  loss  0.277660 validation0.616400
# Epoch 12, CIFAR-10 Batch 1:  loss  0.607299 validation0.613600
# Epoch 12, CIFAR-10 Batch 2:  loss  0.375942 validation0.611800
# Epoch 12, CIFAR-10 Batch 3:  loss  0.201317 validation0.621200
# Epoch 12, CIFAR-10 Batch 4:  loss  0.369309 validation0.597800
# Epoch 12, CIFAR-10 Batch 5:  loss  0.298397 validation0.600000
# Epoch 13, CIFAR-10 Batch 1:  loss  0.525137 validation0.616800
# Epoch 13, CIFAR-10 Batch 2:  loss  0.316191 validation0.617000
# Epoch 13, CIFAR-10 Batch 3:  loss  0.172746 validation0.619800
# Epoch 13, CIFAR-10 Batch 4:  loss  0.323116 validation0.599200
# Epoch 13, CIFAR-10 Batch 5:  loss  0.234729 validation0.601600
# Epoch 14, CIFAR-10 Batch 1:  loss  0.449691 validation0.618600
# Epoch 14, CIFAR-10 Batch 2:  loss  0.250165 validation0.624000
# Epoch 14, CIFAR-10 Batch 3:  loss  0.158228 validation0.616600
# Epoch 14, CIFAR-10 Batch 4:  loss  0.296009 validation0.611400
# Epoch 14, CIFAR-10 Batch 5:  loss  0.176449 validation0.618000
# Epoch 15, CIFAR-10 Batch 1:  loss  0.386731 validation0.614800
# Epoch 15, CIFAR-10 Batch 2:  loss  0.192341 validation0.625600
# Epoch 15, CIFAR-10 Batch 3:  loss  0.120297 validation0.619600
# Epoch 15, CIFAR-10 Batch 4:  loss  0.292988 validation0.614600
# Epoch 15, CIFAR-10 Batch 5:  loss  0.184405 validation0.603000
# Epoch 16, CIFAR-10 Batch 1:  loss  0.280355 validation0.610000
# Epoch 16, CIFAR-10 Batch 2:  loss  0.211455 validation0.611200
# Epoch 16, CIFAR-10 Batch 3:  loss  0.105391 validation0.617400
# Epoch 16, CIFAR-10 Batch 4:  loss  0.188101 validation0.617400
# Epoch 16, CIFAR-10 Batch 5:  loss  0.141655 validation0.619600
# Epoch 17, CIFAR-10 Batch 1:  loss  0.248980 validation0.598800
# Epoch 17, CIFAR-10 Batch 2:  loss  0.184137 validation0.608800
# Epoch 17, CIFAR-10 Batch 3:  loss  0.153763 validation0.613400
# Epoch 17, CIFAR-10 Batch 4:  loss  0.192141 validation0.617000
# Epoch 17, CIFAR-10 Batch 5:  loss  0.100627 validation0.623200
# Epoch 18, CIFAR-10 Batch 1:  loss  0.184293 validation0.606200
# Epoch 18, CIFAR-10 Batch 2:  loss  0.077728 validation0.611400
# Epoch 18, CIFAR-10 Batch 3:  loss  0.116891 validation0.614600
# Epoch 18, CIFAR-10 Batch 4:  loss  0.144494 validation0.623000
# Epoch 18, CIFAR-10 Batch 5:  loss  0.088964 validation0.627000
# Epoch 19, CIFAR-10 Batch 1:  loss  0.146519 validation0.611400
# Epoch 19, CIFAR-10 Batch 2:  loss  0.099842 validation0.602000
# Epoch 19, CIFAR-10 Batch 3:  loss  0.097372 validation0.610800
# Epoch 19, CIFAR-10 Batch 4:  loss  0.126303 validation0.609000
# Epoch 19, CIFAR-10 Batch 5:  loss  0.070485 validation0.636200
# Epoch 20, CIFAR-10 Batch 1:  loss  0.106274 validation0.615000
# Epoch 20, CIFAR-10 Batch 2:  loss  0.083541 validation0.602000
# Epoch 20, CIFAR-10 Batch 3:  loss  0.076871 validation0.605200
# Epoch 20, CIFAR-10 Batch 4:  loss  0.130867 validation0.605200
# Epoch 20, CIFAR-10 Batch 5:  loss  0.061933 validation0.627800
# Epoch 21, CIFAR-10 Batch 1:  loss  0.115958 validation0.619000
# Epoch 21, CIFAR-10 Batch 2:  loss  0.050492 validation0.609800
# Epoch 21, CIFAR-10 Batch 3:  loss  0.047081 validation0.613400
# Epoch 21, CIFAR-10 Batch 4:  loss  0.107531 validation0.614200
# Epoch 21, CIFAR-10 Batch 5:  loss  0.046609 validation0.610200
# Epoch 22, CIFAR-10 Batch 1:  loss  0.077147 validation0.620200
# Epoch 22, CIFAR-10 Batch 2:  loss  0.051070 validation0.603600
# Epoch 22, CIFAR-10 Batch 3:  loss  0.046131 validation0.615800
# Epoch 22, CIFAR-10 Batch 4:  loss  0.079504 validation0.620600
# Epoch 22, CIFAR-10 Batch 5:  loss  0.051484 validation0.618600
# Epoch 23, CIFAR-10 Batch 1:  loss  0.070123 validation0.620000
# Epoch 23, CIFAR-10 Batch 2:  loss  0.045679 validation0.619000
# Epoch 23, CIFAR-10 Batch 3:  loss  0.048103 validation0.613600
# Epoch 23, CIFAR-10 Batch 4:  loss  0.072943 validation0.617800
# Epoch 23, CIFAR-10 Batch 5:  loss  0.062259 validation0.620400
# Epoch 24, CIFAR-10 Batch 1:  loss  0.074053 validation0.616400
# Epoch 24, CIFAR-10 Batch 2:  loss  0.040938 validation0.608400
# Epoch 24, CIFAR-10 Batch 3:  loss  0.043486 validation0.623200
# Epoch 24, CIFAR-10 Batch 4:  loss  0.107341 validation0.609000
# Epoch 24, CIFAR-10 Batch 5:  loss  0.042444 validation0.617400
# Epoch 25, CIFAR-10 Batch 1:  loss  0.069513 validation0.617400
# Epoch 25, CIFAR-10 Batch 2:  loss  0.068282 validation0.604800
# Epoch 25, CIFAR-10 Batch 3:  loss  0.031995 validation0.607800
# Epoch 25, CIFAR-10 Batch 4:  loss  0.075214 validation0.612800
# Epoch 25, CIFAR-10 Batch 5:  loss  0.038241 validation0.624400
# Epoch 26, CIFAR-10 Batch 1:  loss  0.049007 validation0.615200
# Epoch 26, CIFAR-10 Batch 2:  loss  0.040213 validation0.606000
# Epoch 26, CIFAR-10 Batch 3:  loss  0.036969 validation0.603000
# Epoch 26, CIFAR-10 Batch 4:  loss  0.071976 validation0.612600
# Epoch 26, CIFAR-10 Batch 5:  loss  0.026931 validation0.630400
# Epoch 27, CIFAR-10 Batch 1:  loss  0.052650 validation0.616600
# Epoch 27, CIFAR-10 Batch 2:  loss  0.038786 validation0.589800
# Epoch 27, CIFAR-10 Batch 3:  loss  0.027915 validation0.600000
# Epoch 27, CIFAR-10 Batch 4:  loss  0.076461 validation0.597800
# Epoch 27, CIFAR-10 Batch 5:  loss  0.028787 validation0.619200
# Epoch 28, CIFAR-10 Batch 1:  loss  0.063841 validation0.613000
# Epoch 28, CIFAR-10 Batch 2:  loss  0.023626 validation0.600400
# Epoch 28, CIFAR-10 Batch 3:  loss  0.046089 validation0.608000
# Epoch 28, CIFAR-10 Batch 4:  loss  0.067718 validation0.617400
# Epoch 28, CIFAR-10 Batch 5:  loss  0.027438 validation0.622600
# Epoch 29, CIFAR-10 Batch 1:  loss  0.052711 validation0.618000
# Epoch 29, CIFAR-10 Batch 2:  loss  0.028694 validation0.597000
# Epoch 29, CIFAR-10 Batch 3:  loss  0.020895 validation0.614800
# Epoch 29, CIFAR-10 Batch 4:  loss  0.030970 validation0.616600
# Epoch 29, CIFAR-10 Batch 5:  loss  0.027838 validation0.610600
# Epoch 30, CIFAR-10 Batch 1:  loss  0.049721 validation0.609600
# Epoch 30, CIFAR-10 Batch 2:  loss  0.044097 validation0.610400
# Epoch 30, CIFAR-10 Batch 3:  loss  0.030364 validation0.621800
# Epoch 30, CIFAR-10 Batch 4:  loss  0.061602 validation0.600400
# Epoch 30, CIFAR-10 Batch 5:  loss  0.018796 validation0.617800
# Epoch 31, CIFAR-10 Batch 1:  loss  0.040148 validation0.616000
# Epoch 31, CIFAR-10 Batch 2:  loss  0.040630 validation0.606400
# Epoch 31, CIFAR-10 Batch 3:  loss  0.014914 validation0.616400
# Epoch 31, CIFAR-10 Batch 4:  loss  0.015842 validation0.612200
# Epoch 31, CIFAR-10 Batch 5:  loss  0.021946 validation0.622400
# Epoch 32, CIFAR-10 Batch 1:  loss  0.031328 validation0.613000
# Epoch 32, CIFAR-10 Batch 2:  loss  0.020251 validation0.611000
# Epoch 32, CIFAR-10 Batch 3:  loss  0.019500 validation0.616200
# Epoch 32, CIFAR-10 Batch 4:  loss  0.020277 validation0.618400
# Epoch 32, CIFAR-10 Batch 5:  loss  0.025186 validation0.627800
# Epoch 33, CIFAR-10 Batch 1:  loss  0.022798 validation0.616000
# Epoch 33, CIFAR-10 Batch 2:  loss  0.011146 validation0.607600
# Epoch 33, CIFAR-10 Batch 3:  loss  0.011910 validation0.616200
# Epoch 33, CIFAR-10 Batch 4:  loss  0.028072 validation0.622000
# Epoch 33, CIFAR-10 Batch 5:  loss  0.017820 validation0.631000
# Epoch 34, CIFAR-10 Batch 1:  loss  0.022164 validation0.608800
# Epoch 34, CIFAR-10 Batch 2:  loss  0.010843 validation0.621400
# Epoch 34, CIFAR-10 Batch 3:  loss  0.015064 validation0.614600
# Epoch 34, CIFAR-10 Batch 4:  loss  0.016077 validation0.620800
# Epoch 34, CIFAR-10 Batch 5:  loss  0.023326 validation0.627600
# Epoch 35, CIFAR-10 Batch 1:  loss  0.062618 validation0.613600
# Epoch 35, CIFAR-10 Batch 2:  loss  0.011072 validation0.604000
# Epoch 35, CIFAR-10 Batch 3:  loss  0.020348 validation0.614200
# Epoch 35, CIFAR-10 Batch 4:  loss  0.015517 validation0.618400
# Epoch 35, CIFAR-10 Batch 5:  loss  0.006389 validation0.612400
# Epoch 36, CIFAR-10 Batch 1:  loss  0.023404 validation0.612000
# Epoch 36, CIFAR-10 Batch 2:  loss  0.012834 validation0.602400
# Epoch 36, CIFAR-10 Batch 3:  loss  0.021898 validation0.614000
# Epoch 36, CIFAR-10 Batch 4:  loss  0.015781 validation0.617000
# Epoch 36, CIFAR-10 Batch 5:  loss  0.029659 validation0.608000
# Epoch 37, CIFAR-10 Batch 1:  loss  0.032156 validation0.615000
# Epoch 37, CIFAR-10 Batch 2:  loss  0.021589 validation0.610400
# Epoch 37, CIFAR-10 Batch 3:  loss  0.016943 validation0.604000
# Epoch 37, CIFAR-10 Batch 4:  loss  0.016898 validation0.621200
# Epoch 37, CIFAR-10 Batch 5:  loss  0.024005 validation0.596200
# Epoch 38, CIFAR-10 Batch 1:  loss  0.056454 validation0.605000
# Epoch 38, CIFAR-10 Batch 2:  loss  0.007685 validation0.618400
# Epoch 38, CIFAR-10 Batch 3:  loss  0.007679 validation0.618800
# Epoch 38, CIFAR-10 Batch 4:  loss  0.022591 validation0.613800
# Epoch 38, CIFAR-10 Batch 5:  loss  0.020143 validation0.618400
# Epoch 39, CIFAR-10 Batch 1:  loss  0.036740 validation0.608800
# Epoch 39, CIFAR-10 Batch 2:  loss  0.005025 validation0.617800
# Epoch 39, CIFAR-10 Batch 3:  loss  0.008070 validation0.614000
# Epoch 39, CIFAR-10 Batch 4:  loss  0.025671 validation0.610800
# Epoch 39, CIFAR-10 Batch 5:  loss  0.005835 validation0.619000
# Epoch 40, CIFAR-10 Batch 1:  loss  0.012852 validation0.610000
# Epoch 40, CIFAR-10 Batch 2:  loss  0.008919 validation0.605600
# Epoch 40, CIFAR-10 Batch 3:  loss  0.012658 validation0.629600
# Epoch 40, CIFAR-10 Batch 4:  loss  0.009563 validation0.617400
# Epoch 40, CIFAR-10 Batch 5:  loss  0.016663 validation0.624400
# Epoch 41, CIFAR-10 Batch 1:  loss  0.012909 validation0.614600
# Epoch 41, CIFAR-10 Batch 2:  loss  0.006694 validation0.610800
# Epoch 41, CIFAR-10 Batch 3:  loss  0.012533 validation0.625200
# Epoch 41, CIFAR-10 Batch 4:  loss  0.012859 validation0.618600
# Epoch 41, CIFAR-10 Batch 5:  loss  0.006662 validation0.617600
# Epoch 42, CIFAR-10 Batch 1:  loss  0.009711 validation0.608200
# Epoch 42, CIFAR-10 Batch 2:  loss  0.021257 validation0.615200
# Epoch 42, CIFAR-10 Batch 3:  loss  0.011744 validation0.621600
# Epoch 42, CIFAR-10 Batch 4:  loss  0.009632 validation0.619000
# Epoch 42, CIFAR-10 Batch 5:  loss  0.006689 validation0.628000
# Epoch 43, CIFAR-10 Batch 1:  loss  0.012482 validation0.590000
# Epoch 43, CIFAR-10 Batch 2:  loss  0.007506 validation0.616600
# Epoch 43, CIFAR-10 Batch 3:  loss  0.005968 validation0.614400
# Epoch 43, CIFAR-10 Batch 4:  loss  0.004147 validation0.616400
# Epoch 43, CIFAR-10 Batch 5:  loss  0.006570 validation0.615800
# Epoch 44, CIFAR-10 Batch 1:  loss  0.012133 validation0.599200
# Epoch 44, CIFAR-10 Batch 2:  loss  0.010954 validation0.605800
# Epoch 44, CIFAR-10 Batch 3:  loss  0.010228 validation0.624600
# Epoch 44, CIFAR-10 Batch 4:  loss  0.006614 validation0.614400
# Epoch 44, CIFAR-10 Batch 5:  loss  0.006327 validation0.626600
# Epoch 45, CIFAR-10 Batch 1:  loss  0.006575 validation0.614000
# Epoch 45, CIFAR-10 Batch 2:  loss  0.004602 validation0.615600
# Epoch 45, CIFAR-10 Batch 3:  loss  0.005450 validation0.617600
# Epoch 45, CIFAR-10 Batch 4:  loss  0.009378 validation0.624800
# Epoch 45, CIFAR-10 Batch 5:  loss  0.003946 validation0.624800
# Epoch 46, CIFAR-10 Batch 1:  loss  0.014764 validation0.609000
# Epoch 46, CIFAR-10 Batch 2:  loss  0.006666 validation0.608800
# Epoch 46, CIFAR-10 Batch 3:  loss  0.006286 validation0.628200
# Epoch 46, CIFAR-10 Batch 4:  loss  0.010805 validation0.613000
# Epoch 46, CIFAR-10 Batch 5:  loss  0.005886 validation0.636000
# Epoch 47, CIFAR-10 Batch 1:  loss  0.005340 validation0.608600
# Epoch 47, CIFAR-10 Batch 2:  loss  0.004671 validation0.614800
# Epoch 47, CIFAR-10 Batch 3:  loss  0.009693 validation0.614800
# Epoch 47, CIFAR-10 Batch 4:  loss  0.007923 validation0.605600
# Epoch 47, CIFAR-10 Batch 5:  loss  0.012372 validation0.624600
# Epoch 48, CIFAR-10 Batch 1:  loss  0.010541 validation0.610800
# Epoch 48, CIFAR-10 Batch 2:  loss  0.005221 validation0.611600
# Epoch 48, CIFAR-10 Batch 3:  loss  0.003563 validation0.615000
# Epoch 48, CIFAR-10 Batch 4:  loss  0.007476 validation0.611800
# Epoch 48, CIFAR-10 Batch 5:  loss  0.002749 validation0.628200
# Epoch 49, CIFAR-10 Batch 1:  loss  0.007082 validation0.610000
# Epoch 49, CIFAR-10 Batch 2:  loss  0.005519 validation0.604600
# Epoch 49, CIFAR-10 Batch 3:  loss  0.004954 validation0.614000
# Epoch 49, CIFAR-10 Batch 4:  loss  0.012105 validation0.618600
# Epoch 49, CIFAR-10 Batch 5:  loss  0.005249 validation0.630000
# Epoch 50, CIFAR-10 Batch 1:  loss  0.013161 validation0.620800
# Epoch 50, CIFAR-10 Batch 2:  loss  0.003393 validation0.607000
# Epoch 50, CIFAR-10 Batch 3:  loss  0.019073 validation0.616600
# Epoch 50, CIFAR-10 Batch 4:  loss  0.016720 validation0.610800
# Epoch 50, CIFAR-10 Batch 5:  loss  0.006469 validation0.615000
# Epoch 51, CIFAR-10 Batch 1:  loss  0.002979 validation0.615400
# Epoch 51, CIFAR-10 Batch 2:  loss  0.006937 validation0.615200
# Epoch 51, CIFAR-10 Batch 3:  loss  0.006547 validation0.613400
# Epoch 51, CIFAR-10 Batch 4:  loss  0.003812 validation0.619400
# Epoch 51, CIFAR-10 Batch 5:  loss  0.004200 validation0.629600
# Epoch 52, CIFAR-10 Batch 1:  loss  0.006892 validation0.610600
# Epoch 52, CIFAR-10 Batch 2:  loss  0.006423 validation0.623800
# Epoch 52, CIFAR-10 Batch 3:  loss  0.009594 validation0.616000
# Epoch 52, CIFAR-10 Batch 4:  loss  0.010477 validation0.623600
# Epoch 52, CIFAR-10 Batch 5:  loss  0.003499 validation0.624400
# Epoch 53, CIFAR-10 Batch 1:  loss  0.002576 validation0.617200
# Epoch 53, CIFAR-10 Batch 2:  loss  0.008406 validation0.611400
# Epoch 53, CIFAR-10 Batch 3:  loss  0.001844 validation0.630400
# Epoch 53, CIFAR-10 Batch 4:  loss  0.013723 validation0.615400
# Epoch 53, CIFAR-10 Batch 5:  loss  0.010831 validation0.634000
# Epoch 54, CIFAR-10 Batch 1:  loss  0.007657 validation0.607600
# Epoch 54, CIFAR-10 Batch 2:  loss  0.004969 validation0.618200
# Epoch 54, CIFAR-10 Batch 3:  loss  0.002552 validation0.627200
# Epoch 54, CIFAR-10 Batch 4:  loss  0.004581 validation0.621400
# Epoch 54, CIFAR-10 Batch 5:  loss  0.007738 validation0.626600
# Epoch 55, CIFAR-10 Batch 1:  loss  0.008510 validation0.620200
# Epoch 55, CIFAR-10 Batch 2:  loss  0.003512 validation0.618000
# Epoch 55, CIFAR-10 Batch 3:  loss  0.003248 validation0.617800
# Epoch 55, CIFAR-10 Batch 4:  loss  0.003552 validation0.626600
# Epoch 55, CIFAR-10 Batch 5:  loss  0.002799 validation0.633800
# Epoch 56, CIFAR-10 Batch 1:  loss  0.008466 validation0.618600
# Epoch 56, CIFAR-10 Batch 2:  loss  0.007892 validation0.614200
# Epoch 56, CIFAR-10 Batch 3:  loss  0.004050 validation0.620200
# Epoch 56, CIFAR-10 Batch 4:  loss  0.007094 validation0.624400
# Epoch 56, CIFAR-10 Batch 5:  loss  0.008522 validation0.620600
# Epoch 57, CIFAR-10 Batch 1:  loss  0.020581 validation0.615200
# Epoch 57, CIFAR-10 Batch 2:  loss  0.003758 validation0.615400
# Epoch 57, CIFAR-10 Batch 3:  loss  0.003401 validation0.615000
# Epoch 57, CIFAR-10 Batch 4:  loss  0.004175 validation0.618800
# Epoch 57, CIFAR-10 Batch 5:  loss  0.004158 validation0.624800
# Epoch 58, CIFAR-10 Batch 1:  loss  0.004611 validation0.621600
# Epoch 58, CIFAR-10 Batch 2:  loss  0.004173 validation0.622800
# Epoch 58, CIFAR-10 Batch 3:  loss  0.040665 validation0.618400
# Epoch 58, CIFAR-10 Batch 4:  loss  0.006873 validation0.623200
# Epoch 58, CIFAR-10 Batch 5:  loss  0.006445 validation0.623800
# Epoch 59, CIFAR-10 Batch 1:  loss  0.005178 validation0.617800
# Epoch 59, CIFAR-10 Batch 2:  loss  0.003219 validation0.620800
# Epoch 59, CIFAR-10 Batch 3:  loss  0.004783 validation0.620400
# Epoch 59, CIFAR-10 Batch 4:  loss  0.004961 validation0.626800
# Epoch 59, CIFAR-10 Batch 5:  loss  0.002397 validation0.625800
# Epoch 60, CIFAR-10 Batch 1:  loss  0.003355 validation0.627000
# Epoch 60, CIFAR-10 Batch 2:  loss  0.005465 validation0.605400
# Epoch 60, CIFAR-10 Batch 3:  loss  0.002418 validation0.622000
# Epoch 60, CIFAR-10 Batch 4:  loss  0.008752 validation0.631600
# Epoch 60, CIFAR-10 Batch 5:  loss  0.003399 validation0.622200
# Epoch 61, CIFAR-10 Batch 1:  loss  0.004581 validation0.625400
# Epoch 61, CIFAR-10 Batch 2:  loss  0.014175 validation0.610200
# Epoch 61, CIFAR-10 Batch 3:  loss  0.003616 validation0.625000
# Epoch 61, CIFAR-10 Batch 4:  loss  0.006934 validation0.621400
# Epoch 61, CIFAR-10 Batch 5:  loss  0.006965 validation0.616200
# Epoch 62, CIFAR-10 Batch 1:  loss  0.005839 validation0.612600
# Epoch 62, CIFAR-10 Batch 2:  loss  0.002330 validation0.620800
# Epoch 62, CIFAR-10 Batch 3:  loss  0.003237 validation0.609000
# Epoch 62, CIFAR-10 Batch 4:  loss  0.003567 validation0.625000
# Epoch 62, CIFAR-10 Batch 5:  loss  0.003608 validation0.629200
# Epoch 63, CIFAR-10 Batch 1:  loss  0.002957 validation0.615200
# Epoch 63, CIFAR-10 Batch 2:  loss  0.005516 validation0.608600
# Epoch 63, CIFAR-10 Batch 3:  loss  0.002201 validation0.625600
# Epoch 63, CIFAR-10 Batch 4:  loss  0.009765 validation0.598000
# Epoch 63, CIFAR-10 Batch 5:  loss  0.008759 validation0.620400
# Epoch 64, CIFAR-10 Batch 1:  loss  0.011694 validation0.616400
# Epoch 64, CIFAR-10 Batch 2:  loss  0.005388 validation0.624200
# Epoch 64, CIFAR-10 Batch 3:  loss  0.002298 validation0.618800
# Epoch 64, CIFAR-10 Batch 4:  loss  0.006128 validation0.627600
# Epoch 64, CIFAR-10 Batch 5:  loss  0.004360 validation0.625200
# Epoch 65, CIFAR-10 Batch 1:  loss  0.002841 validation0.625800
# Epoch 65, CIFAR-10 Batch 2:  loss  0.003013 validation0.617000
# Epoch 65, CIFAR-10 Batch 3:  loss  0.007278 validation0.622800
# Epoch 65, CIFAR-10 Batch 4:  loss  0.007580 validation0.616600
# Epoch 65, CIFAR-10 Batch 5:  loss  0.015993 validation0.614000
# Epoch 66, CIFAR-10 Batch 1:  loss  0.003573 validation0.623200
# Epoch 66, CIFAR-10 Batch 2:  loss  0.004591 validation0.616400
# Epoch 66, CIFAR-10 Batch 3:  loss  0.001261 validation0.621800
# Epoch 66, CIFAR-10 Batch 4:  loss  0.005127 validation0.612400
# Epoch 66, CIFAR-10 Batch 5:  loss  0.002074 validation0.636200
# Epoch 67, CIFAR-10 Batch 1:  loss  0.010322 validation0.623600
# Epoch 67, CIFAR-10 Batch 2:  loss  0.002762 validation0.612400
# Epoch 67, CIFAR-10 Batch 3:  loss  0.003022 validation0.612800
# Epoch 67, CIFAR-10 Batch 4:  loss  0.003037 validation0.625600
# Epoch 67, CIFAR-10 Batch 5:  loss  0.011634 validation0.620400
# Epoch 68, CIFAR-10 Batch 1:  loss  0.001813 validation0.623400
# Epoch 68, CIFAR-10 Batch 2:  loss  0.002837 validation0.625600
# Epoch 68, CIFAR-10 Batch 3:  loss  0.002785 validation0.623400
# Epoch 68, CIFAR-10 Batch 4:  loss  0.002436 validation0.623800
# Epoch 68, CIFAR-10 Batch 5:  loss  0.001721 validation0.626000
# Epoch 69, CIFAR-10 Batch 1:  loss  0.005467 validation0.612800
# Epoch 69, CIFAR-10 Batch 2:  loss  0.001005 validation0.616200
# Epoch 69, CIFAR-10 Batch 3:  loss  0.003817 validation0.625600
# Epoch 69, CIFAR-10 Batch 4:  loss  0.003483 validation0.629600
# Epoch 69, CIFAR-10 Batch 5:  loss  0.002949 validation0.624800
# Epoch 70, CIFAR-10 Batch 1:  loss  0.003332 validation0.621800
# Epoch 70, CIFAR-10 Batch 2:  loss  0.006554 validation0.614800
# Epoch 70, CIFAR-10 Batch 3:  loss  0.003057 validation0.624800
# Epoch 70, CIFAR-10 Batch 4:  loss  0.004742 validation0.627200
# Epoch 70, CIFAR-10 Batch 5:  loss  0.000732 validation0.630400
# Epoch 71, CIFAR-10 Batch 1:  loss  0.008417 validation0.612600
# Epoch 71, CIFAR-10 Batch 2:  loss  0.003335 validation0.619000
# Epoch 71, CIFAR-10 Batch 3:  loss  0.001964 validation0.622000
# Epoch 71, CIFAR-10 Batch 4:  loss  0.004720 validation0.619600
# Epoch 71, CIFAR-10 Batch 5:  loss  0.003234 validation0.628800
# Epoch 72, CIFAR-10 Batch 1:  loss  0.003336 validation0.626400
# Epoch 72, CIFAR-10 Batch 2:  loss  0.003645 validation0.618800
# Epoch 72, CIFAR-10 Batch 3:  loss  0.003523 validation0.621600
# Epoch 72, CIFAR-10 Batch 4:  loss  0.010449 validation0.616000
# Epoch 72, CIFAR-10 Batch 5:  loss  0.003510 validation0.630600
# Epoch 73, CIFAR-10 Batch 1:  loss  0.007483 validation0.620600
# Epoch 73, CIFAR-10 Batch 2:  loss  0.003458 validation0.627800
# Epoch 73, CIFAR-10 Batch 3:  loss  0.001445 validation0.626400
# Epoch 73, CIFAR-10 Batch 4:  loss  0.004158 validation0.626200
# Epoch 73, CIFAR-10 Batch 5:  loss  0.002459 validation0.639800
# Epoch 74, CIFAR-10 Batch 1:  loss  0.006601 validation0.624800
# Epoch 74, CIFAR-10 Batch 2:  loss  0.000831 validation0.625800
# Epoch 74, CIFAR-10 Batch 3:  loss  0.002838 validation0.627400
# Epoch 74, CIFAR-10 Batch 4:  loss  0.009191 validation0.619000
# Epoch 74, CIFAR-10 Batch 5:  loss  0.004292 validation0.637600
# Epoch 75, CIFAR-10 Batch 1:  loss  0.001839 validation0.624800
# Epoch 75, CIFAR-10 Batch 2:  loss  0.003541 validation0.615800
# Epoch 75, CIFAR-10 Batch 3:  loss  0.005022 validation0.621600
# Epoch 75, CIFAR-10 Batch 4:  loss  0.003077 validation0.626400
# Epoch 75, CIFAR-10 Batch 5:  loss  0.004014 validation0.624400

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.620238329839269

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
